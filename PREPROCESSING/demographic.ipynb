# %% [markdown]
# Packages

# %%
import pandas as pd
import numpy as np
from pathlib import Path
# dates & cleaning
import re
import warnings
warnings.filterwarnings("ignore")
# optional: show full tables in console
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# %%
#
demo_file = "../DATA/Amsterdam Region districts and neigbourhood data.xlsx"
# read file
demo = pd.read_excel(demo_file, skiprows=1)
# check
print("Demographics shape:", demo.shape)
print("\nDemographics columns:")
print(demo.columns)
# Out:
# Demographics shape: (583, 22)
#
# Demographics columns:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='str')

# %%
def clean_demo_sheet(file, year):
    year = str(year)
    if year == "2025":
        raw = pd.read_excel(demo_file, sheet_name=year, header=None, skiprows=3)
    elif year == "2024":
        raw = pd.read_excel(demo_file, sheet_name=year, header=None, skiprows=1)
    else:
        raw = pd.read_excel(demo_file, sheet_name=year, header=None)

    top = raw.iloc[0]      # group titles
    bottom = raw.iloc[1]   # column titles

    columns = []

    for t, b in zip(top, bottom):

        t = str(t).strip()
        b = str(b).strip()

        if b == "#" or b == "nan":
            columns.append(t)

        elif t == "nan":
            columns.append(b)

        else:
            columns.append(f"{t} {b}")

    # actual data starts row 2
    df = raw.iloc[2:].copy()
    df.columns = columns
    df = df.reset_index(drop=True)

    # remove empty rows
    df = df[df.iloc[:,0].notna()]
    return df

# %%
df2025 = clean_demo_sheet(demo_file, 2025)
df2024 = clean_demo_sheet(demo_file, 2024)
df2023 = clean_demo_sheet(demo_file, 2023)
df2022 = clean_demo_sheet(demo_file, 2022)
df2021 = clean_demo_sheet(demo_file, 2021)
df2020 = clean_demo_sheet(demo_file, 2020)

# %%
df2025.head()
# Out:
#   Districts & Neigbourhoods Type of region  Regioncode Total population     Man   Woman  \
# 0                 Amsterdam   Municipality      GM0363           873338  433550  439788
# 1     Burgwallen-Oude Zijde       District    WK036300             4520    2485    2040
# 2               Kop Zeedijk  Neighbourhood  BU03630000             1115     650     465
# 3            Oude Kerk e.o.  Neighbourhood  BU03630001              695     390     305
# 4           Burgwallen Oost  Neighbourhood  BU03630002             1650     860     790
#
#   Population| Age group |0 tot 15 year Population| Age group |15 tot 25 year Population| Age group |25 tot 45 year  \
# 0                               123066                                109208                                317606
# 1                                  205                                   780                                  2140
# 2                                   40                                   145                                   555
# 3                                   20                                   150                                   340
# 4                                   90                                   285                                   770
#
#   Population| Age group |45 tot 65 year Population| Age group |65+ year Births Deaths Total households  \
# 0                                210029                          113429  10779   5914           474875
# 1                                   945                             445     35     20             3180
# 2                                   275                             100      5      5              770
# 3                                   125                              70      5      0              510
# 4                                   325                             180     15      5             1145
#
#   Single-person households Households without children Households with children Average household size  \
# 0                   256596                      104309                   113970                    1,8
# 1                     2155                         780                      245                    1,4
# 2                      520                         200                       50                    1,4
# 3                      350                         130                       30                    1,4
# 4                      760                         285                      105                    1,4
#
#   Care|Young people receiving youth care Healthcare|Wmo clients ZIPcode  Year
# 0                                  21295                  65685       .  2025
# 1                                     35                    130       .  2025
# 2                                      .                     50    1012  2025
# 3                                      .                     15    1012  2025
# 4                                     25                     40    1012  2025

# %%
df2024.head()
# Out:
#   Districts & Neigbourhoods Type of region  Regioncode Total population     Man   Woman  \
# 0                 Amsterdam   Municipality      GM0363           931298  460766  470532
# 1           Haarlemmerbuurt       District    WK0363AA             9180    4570    4610
# 2       Planciusbuurt-Noord  Neighbourhood  BU0363AA01              345     185     160
# 3       Westelijke eilanden  Neighbourhood  BU0363AA02             2895    1375    1520
# 4          Westerdokseiland  Neighbourhood  BU0363AA03             1850     945     900
#
#   Population| Age group |0 tot 15 year Population| Age group |15 tot 25 year Population| Age group |25 tot 45 year  \
# 0                               122836                                124148                                343274
# 1                                  785                                   915                                  3090
# 2                                   20                                    25                                   165
# 3                                  275                                   270                                   920
# 4                                  205                                   150                                   540
#
#   Population| Age group |45 tot 65 year Population| Age group |65+ year Births Deaths Total households  \
# 0                                214560                          126480   9797   6021           515181
# 1                                  2530                            1865     55     65             5765
# 2                                   100                              35      0      5              260
# 3                                   815                             610     20     20             1835
# 4                                   530                             420     15      5             1000
#
#   Single-person households Households without children Households with children Average household size  \
# 0                   283997                      114010                   117174                    1,8
# 1                     3505                        1395                      870                    1,6
# 2                      190                          45                       20                    1,3
# 3                     1150                         400                      295                    1,6
# 4                      450                         335                      220                    1,8
#
#   Care|Young people receiving youth care Healthcare|Wmo clients ZIPcode  Year
# 0                                  21200                  67885       .  2024
# 1                                    135                    650       .  2024
# 2                                      .                     15    1013  2024
# 3                                     60                    170    1013  2024
# 4                                     25                    145    1013  2024

# %%
df2023.head()
# Out:
#   Districts & Neigbourhoods Type of region  Regioncode Total population     Man   Woman  \
# 0                 Amsterdam   Municipality      GM0363           918117  454273  463844
# 1           Haarlemmerbuurt       District    WK0363AA             9135    4565    4570
# 2       Planciusbuurt-Noord  Neighbourhood  BU0363AA01              345     180     160
# 3       Westelijke eilanden  Neighbourhood  BU0363AA02             2910    1395    1520
# 4          Westerdokseiland  Neighbourhood  BU0363AA03             1825     925     900
#
#   Population| Age group |0 tot 15 year Population| Age group |15 tot 25 year Population| Age group |25 tot 45 year  \
# 0                               124270                                120404                                335216
# 1                                  810                                   855                                  3055
# 2                                   15                                    25                                   180
# 3                                  290                                   260                                   910
# 4                                  210                                   140                                   515
#
#   Population| Age group |45 tot 65 year Population| Age group |65+ year Births Deaths Total households  \
# 0                                215053                          123174   9673   5977           505705
# 1                                  2640                            1775     70     65             5695
# 2                                    90                              35      5      5              255
# 3                                   870                             585     25     15             1840
# 4                                   550                             410     15     10              990
#
#   Single-person households Households without children Households with children Average household size  \
# 0                   277385                      111234                   117086                    1,8
# 1                     3410                        1405                      875                    1,6
# 2                      185                          50                       20                    1,3
# 3                     1140                         400                      295                    1,6
# 4                      445                         330                      215                    1,8
#
#   Care|Young people receiving youth care Healthcare|Wmo clients ZIPcode  Year
# 0                                  22555                  67055       .  2023
# 1                                    155                    630       .  2023
# 2                                    NaN                     10    1013  2023
# 3                                     55                    160    1013  2023
# 4                                     30                    145    1013  2023

# %%
df2022.head()
# Out:
#   Districts & Neigbourhoods Type of region  Regioncode Total population     Man   Woman  \
# 0                 Amsterdam   Municipality      GM0363           882633  437582  445051
# 1     Burgwallen-Oude Zijde       District    WK036300             4550    2515    2030
# 2               Kop Zeedijk  Neighbourhood  BU03630000             1135     640     495
# 3            Oude Kerk e.o.  Neighbourhood  BU03630001              705     400     305
# 4           Burgwallen Oost  Neighbourhood  BU03630002             1630     880     755
#
#   Population| Age group |0 tot 15 year Population| Age group |15 tot 25 year Population| Age group |25 tot 45 year  \
# 0                               121642                                115117                                320787
# 1                                  205                                   865                                  2100
# 2                                   45                                   155                                   565
# 3                                   20                                   170                                   325
# 4                                   85                                   335                                   720
#
#   Population| Age group |45 tot 65 year Population| Age group |65+ year Births Deaths Total households  \
# 0                                209094                          115993   9657   5788           484574
# 1                                   920                             445     25     20             3245
# 2                                   265                             100      5      5              825
# 3                                   115                              70      5      5              515
# 4                                   325                             165     10     10             1135
#
#   Single-person households Households without children Households with children Average household size  \
# 0                   265133                      105998                   113443                    1,8
# 1                     2230                         770                      245                    1,4
# 2                      575                         195                       55                    1,4
# 3                      355                         135                       30                    1,4
# 4                      770                         265                      100                    1,4
#
#   Care|Young people receiving youth care Healthcare|Wmo clients ZIPcode  Year
# 0                                  21590                  68325       .  2022
# 1                                     35                    125       .  2022
# 2                                     10                     45    1012  2022
# 3                                      .                     15    1012  2022
# 4                                     20                     45    1012  2022

# %%
df2021.head()
# Out:
#   Districts & Neigbourhoods Type of region  Regioncode Total population     Man   Woman  \
# 0                 Amsterdam   Municipality      GM0363           873338  433550  439788
# 1     Burgwallen-Oude Zijde       District    WK036300             4520    2485    2040
# 2               Kop Zeedijk  Neighbourhood  BU03630000             1115     650     465
# 3            Oude Kerk e.o.  Neighbourhood  BU03630001              695     390     305
# 4           Burgwallen Oost  Neighbourhood  BU03630002             1650     860     790
#
#   Population| Age group |0 tot 15 year Population| Age group |15 tot 25 year Population| Age group |25 tot 45 year  \
# 0                               123066                                109208                                317606
# 1                                  205                                   780                                  2140
# 2                                   40                                   145                                   555
# 3                                   20                                   150                                   340
# 4                                   90                                   285                                   770
#
#   Population| Age group |45 tot 65 year Population| Age group |65+ year Births Deaths Total households  \
# 0                                210029                          113429  10779   5914           474875
# 1                                   945                             445     35     20             3180
# 2                                   275                             100      5      5              770
# 3                                   125                              70      5      0              510
# 4                                   325                             180     15      5             1145
#
#   Single-person households Households without children Households with children Average household size  \
# 0                   256596                      104309                   113970                    1,8
# 1                     2155                         780                      245                    1,4
# 2                      520                         200                       50                    1,4
# 3                      350                         130                       30                    1,4
# 4                      760                         285                      105                    1,4
#
#   Care|Young people receiving youth care Healthcare|Wmo clients ZIPcode  Year
# 0                                  21295                  65685       .  2021
# 1                                     35                    130       .  2021
# 2                                      .                     50    1012  2021
# 3                                      .                     15    1012  2021
# 4                                     25                     40    1012  2021

# %%
df2020.head()
# Out:
#   Districts & Neigbourhoods Type of region  Regioncode Total population     Man   Woman  \
# 0                 Amsterdam   Municipality      GM0363           872757  432879  439878
# 1     Burgwallen-Oude Zijde       District    WK036300             4465    2465    2000
# 2               Kop Zeedijk  Neighbourhood  BU03630000             1100     625     475
# 3            Oude Kerk e.o.  Neighbourhood  BU03630001              730     410     315
# 4           Burgwallen Oost  Neighbourhood  BU03630002             1615     860     755
#
#   Population| Age group |0 tot 15 year Population| Age group |15 tot 25 year Population| Age group |25 tot 45 year  \
# 0                               125119                                108636                                317667
# 1                                  220                                   695                                  2190
# 2                                   50                                   125                                   575
# 3                                   30                                   130                                   370
# 4                                   90                                   255                                   780
#
#   Population| Age group |45 tot 65 year Population| Age group |65+ year Births Deaths Total households  \
# 0                                210376                          110959  10345   5763           475368
# 1                                   940                             425     30     10             3195
# 2                                   275                              75     10      5              760
# 3                                   130                              70     10      0              540
# 4                                   310                             175     15      5             1155
#
#   Single-person households Households without children Households with children Average household size  \
# 0                   258962                      101708                   114698                    1,8
# 1                     2230                         730                      240                    1,4
# 2                      500                         205                       50                    1,4
# 3                      385                         120                       35                    1,3
# 4                      810                         255                       95                    1,4
#
#   Care|Young people receiving youth care Healthcare|Wmo clients ZIPcode  Year
# 0                                  20660                  70580       .  2020
# 1                                     30                    135       .  2020
# 2                                      .                     55    1012  2020
# 3                                      .                     15    1012  2020
# 4                                     15                     45    1012  2020

# %%
demographics = pd.concat([df2020, df2021, df2022, df2023, df2024, df2025], ignore_index=True)

# %%
demographics.head()
# Out:
#   Districts & Neigbourhoods Type of region  Regioncode Total population     Man   Woman  \
# 0                 Amsterdam   Municipality      GM0363           872757  432879  439878
# 1     Burgwallen-Oude Zijde       District    WK036300             4465    2465    2000
# 2               Kop Zeedijk  Neighbourhood  BU03630000             1100     625     475
# 3            Oude Kerk e.o.  Neighbourhood  BU03630001              730     410     315
# 4           Burgwallen Oost  Neighbourhood  BU03630002             1615     860     755
#
#   Population| Age group |0 tot 15 year Population| Age group |15 tot 25 year Population| Age group |25 tot 45 year  \
# 0                               125119                                108636                                317667
# 1                                  220                                   695                                  2190
# 2                                   50                                   125                                   575
# 3                                   30                                   130                                   370
# 4                                   90                                   255                                   780
#
#   Population| Age group |45 tot 65 year Population| Age group |65+ year Births Deaths Total households  \
# 0                                210376                          110959  10345   5763           475368
# 1                                   940                             425     30     10             3195
# 2                                   275                              75     10      5              760
# 3                                   130                              70     10      0              540
# 4                                   310                             175     15      5             1155
#
#   Single-person households Households without children Households with children Average household size  \
# 0                   258962                      101708                   114698                    1,8
# 1                     2230                         730                      240                    1,4
# 2                      500                         205                       50                    1,4
# 3                      385                         120                       35                    1,3
# 4                      810                         255                       95                    1,4
#
#   Care|Young people receiving youth care Healthcare|Wmo clients ZIPcode  Year
# 0                                  20660                  70580       .  2020
# 1                                     30                    135       .  2020
# 2                                      .                     55    1012  2020
# 3                                      .                     15    1012  2020
# 4                                     15                     45    1012  2020

# %%
demographics.shape
# Out:
# (3577, 22)

# %%
text_cols = [
    "Districts & Neigbourhoods",
    "Type of region",
    "Regioncode",
    "Year"
]

num_cols = [c for c in demographics.columns if c not in text_cols]

for col in num_cols:
    demographics[col] = (
        demographics[col]
        .astype(str)
        .str.replace(r'(?<=\d),(?=\d)', '.', regex=True)
        .pipe(pd.to_numeric, errors="coerce")
    )

# %%
demographics = demographics[
    demographics["Type of region"].isin(["Neighbourhood", "District"])
]

# %%
demographics["Type of region"].unique()
# Out:
# <ArrowStringArray>
# ['District', 'Neighbourhood']
# Length: 2, dtype: str

# %%
demographics[num_cols] = demographics[num_cols].fillna(0)

# %% [markdown]
# Education Inicators

# %%
demographics["children_0_15"] = demographics["Population| Age group |0 tot 15 year"]
demographics["youth_15_25"] = demographics["Population| Age group |15 tot 25 year"]
demographics["families_children"] = demographics["Households with children"]

# %% [markdown]
# *Care demand* *INDiCATORS*

# %%
demographics["elderly_65_plus"] = demographics["Population| Age group |65+ year"]
demographics["single_households_ind"] = demographics["Single-person households"]
demographics["youth_care_users"] = demographics["Care|Young people receiving youth care"]
demographics["wmo_users"] = demographics["Healthcare|Wmo clients"]

# %% [markdown]
# YOUTH CARE INDICATORS

# %%
demographics["youth_care_rate"] = demographics["youth_care_users"] / demographics["Total population"] * 1000
demographics["wmo_rate"] = demographics["wmo_users"] / demographics["Total population"] * 1000

# %%
# sort properly
demographics = demographics.sort_values(["Districts & Neigbourhoods", "Year"])

cols = [
    "children_0_15",
    "youth_15_25",
    "elderly_65_plus",
    "families_children",
    "single_households_ind"
]

# growth per district
for c in cols:
    demographics[c + "_growth"] = (
        demographics
        .groupby("Districts & Neigbourhoods")[c]
        .pct_change()
    )

# %%
demographics.head()
# Out:
#      Districts & Neigbourhoods Type of region  Regioncode  Total population   Man  Woman  \
# 530                        AMC  Neighbourhood  BU03639205              35.0  25.0    5.0
# 1110                       AMC  Neighbourhood  BU03639205              30.0  25.0    5.0
# 1690                       AMC  Neighbourhood  BU03639205              30.0  20.0    5.0
# 2316                       AMC  Neighbourhood  BU0363TA06              30.0  25.0    0.0
# 2944                       AMC  Neighbourhood  BU0363TA06              35.0  25.0   10.0
#
#       Population| Age group |0 tot 15 year  Population| Age group |15 tot 25 year  \
# 530                                    0.0                                    0.0
# 1110                                   0.0                                    0.0
# 1690                                   0.0                                    0.0
# 2316                                   0.0                                    0.0
# 2944                                   0.0                                    0.0
#
#       Population| Age group |25 tot 45 year  Population| Age group |45 tot 65 year  Population| Age group |65+ year  \
# 530                                    15.0                                   20.0                              0.0
# 1110                                   10.0                                   20.0                              0.0
# 1690                                   15.0                                   15.0                              0.0
# 2316                                   15.0                                   15.0                              0.0
# 2944                                   15.0                                   15.0                              0.0
#
#       Births  Deaths  Total households  Single-person households  Households without children  \
# 530      0.0     0.0               0.0                       5.0                          0.0
# 1110     0.0     0.0              25.0                      30.0                          0.0
# 1690     0.0     0.0              30.0                      30.0                          0.0
# 2316     0.0     0.0              30.0                      30.0                          0.0
# 2944     0.0     0.0              35.0                      35.0                          0.0
#
#       Households with children  Average household size  Care|Young people receiving youth care  \
# 530                        0.0                     1.0                                     0.0
# 1110                       0.0                     1.0                                     0.0
# 1690                       0.0                     1.0                                     0.0
# 2316                       0.0                     1.0                                     0.0
# 2944                       0.0                     1.0                                     0.0
#
#       Healthcare|Wmo clients  ZIPcode  Year  children_0_15  youth_15_25  families_children  elderly_65_plus  \
# 530                     20.0   1105.0  2020            0.0          0.0                0.0              0.0
# 1110                     0.0   1105.0  2021            0.0          0.0                0.0              0.0
# 1690                    10.0   1105.0  2022            0.0          0.0                0.0              0.0
# 2316                    10.0   1105.0  2023            0.0          0.0                0.0              0.0
# 2944                     0.0   1105.0  2024            0.0          0.0                0.0              0.0
#
#       single_households_ind  youth_care_users  wmo_users  youth_care_rate    wmo_rate  children_0_15_growth  \
# 530                     5.0               0.0       20.0              0.0  571.428571                   NaN
# 1110                   30.0               0.0        0.0              0.0    0.000000                   NaN
# 1690                   30.0               0.0       10.0              0.0  333.333333                   NaN
# 2316                   30.0               0.0       10.0              0.0  333.333333                   NaN
# 2944                   35.0               0.0        0.0              0.0    0.000000                   NaN
#
#       youth_15_25_growth  elderly_65_plus_growth  families_children_growth  single_households_ind_growth
# 530                  NaN                     NaN                       NaN                           NaN
# 1110                 NaN                     NaN                       NaN                      5.000000
# 1690                 NaN                     NaN                       NaN                      0.000000
# 2316                 NaN                     NaN                       NaN                      0.000000
# 2944                 NaN                     NaN                       NaN                      0.166667

# %%
demographics.groupby("Year")["Districts & Neigbourhoods"].nunique()
# Out:
# Year
# 2020    573
# 2021    573
# 2022    573
# 2023    624
# 2024    624
# 2025    573
# Name: Districts & Neigbourhoods, dtype: int64

# %%
demographics[["Districts & Neigbourhoods","Year","children_0_15","children_0_15_growth"]].head(20)
# Out:
#      Districts & Neigbourhoods  Year  children_0_15  children_0_15_growth
# 530                        AMC  2020            0.0                   NaN
# 1110                       AMC  2021            0.0                   NaN
# 1690                       AMC  2022            0.0                   NaN
# 2316                       AMC  2023            0.0                   NaN
# 2944                       AMC  2024            0.0                   NaN
# 3527                       AMC  2025            0.0                   NaN
# 255      Aalsmeerwegbuurt Oost  2020          245.0                   NaN
# 835      Aalsmeerwegbuurt Oost  2021          220.0             -0.102041
# 1415     Aalsmeerwegbuurt Oost  2022          210.0             -0.045455
# 3252     Aalsmeerwegbuurt Oost  2025          220.0              0.047619
# 254      Aalsmeerwegbuurt West  2020          275.0                   NaN
# 834      Aalsmeerwegbuurt West  2021          275.0              0.000000
# 1414     Aalsmeerwegbuurt West  2022          280.0              0.018182
# 3251     Aalsmeerwegbuurt West  2025          275.0             -0.017857
# 2019     Aalsmeerwegbuurt-Oost  2023          200.0                   NaN
# 2647     Aalsmeerwegbuurt-Oost  2024          210.0              0.050000
# 2018     Aalsmeerwegbuurt-West  2023          280.0                   NaN
# 2646     Aalsmeerwegbuurt-West  2024          260.0             -0.071429
# 2308            Aetsveld-Noord  2023          250.0                   NaN
# 2936            Aetsveld-Noord  2024          260.0              0.040000

# %%
demographics.shape
# Out:
# (3566, 36)

# %%
demographics.to_csv("../data_clean/demographics.csv", index=False)

# %%
demographics.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3566 entries, 530 to 3067
# Data columns (total 36 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Districts & Neigbourhoods               3566 non-null   str
#  1   Type of region                          3566 non-null   str
#  2   Regioncode                              3566 non-null   str
#  3   Total population                        3566 non-null   float64
#  4   Man                                     3566 non-null   float64
#  5   Woman                                   3566 non-null   float64
#  6   Population| Age group |0 tot 15 year    3566 non-null   float64
#  7   Population| Age group |15 tot 25 year   3566 non-null   float64
#  8   Population| Age group |25 tot 45 year   3566 non-null   float64
#  9   Population| Age group |45 tot 65 year   3566 non-null   float64
#  10  Population| Age group |65+ year         3566 non-null   float64
#  11  Births                                  3566 non-null   float64
#  12  Deaths                                  3566 non-null   float64
#  13  Total households                        3566 non-null   float64
#  14  Single-person households                3566 non-null   float64
#  15  Households without children             3566 non-null   float64
#  16  Households with children                3566 non-null   float64
#  17  Average household size                  3566 non-null   float64
#  18  Care|Young people receiving youth care  3566 non-null   float64
#  19  Healthcare|Wmo clients                  3566 non-null   float64
#  20  ZIPcode                                 3566 non-null   float64
#  21  Year                                    3566 non-null   object
#  22  children_0_15                           3566 non-null   float64
#  23  youth_15_25                             3566 non-null   float64
#  24  families_children                       3566 non-null   float64
#  25  elderly_65_plus                         3566 non-null   float64
#  26  single_households_ind                   3566 non-null   float64
#  27  youth_care_users                        3566 non-null   float64
#  28  wmo_users                               3566 non-null   float64
#  29  youth_care_rate                         3433 non-null   float64
#  30  wmo_rate                                3433 non-null   float64
#  31  children_0_15_growth                    2488 non-null   float64
#  32  youth_15_25_growth                      2509 non-null   float64
#  33  elderly_65_plus_growth                  2508 non-null   float64
#  34  families_children_growth                2481 non-null   float64
#  35  single_households_ind_growth            2560 non-null   float64
# dtypes: float64(32), object(1), str(3)
# memory usage: 1.1+ MB

# %%
demographics.head()
# Out:
#      Districts & Neigbourhoods Type of region  Regioncode  Total population   Man  Woman  \
# 530                        AMC  Neighbourhood  BU03639205              35.0  25.0    5.0
# 1110                       AMC  Neighbourhood  BU03639205              30.0  25.0    5.0
# 1690                       AMC  Neighbourhood  BU03639205              30.0  20.0    5.0
# 2316                       AMC  Neighbourhood  BU0363TA06              30.0  25.0    0.0
# 2944                       AMC  Neighbourhood  BU0363TA06              35.0  25.0   10.0
#
#       Population| Age group |0 tot 15 year  Population| Age group |15 tot 25 year  \
# 530                                    0.0                                    0.0
# 1110                                   0.0                                    0.0
# 1690                                   0.0                                    0.0
# 2316                                   0.0                                    0.0
# 2944                                   0.0                                    0.0
#
#       Population| Age group |25 tot 45 year  Population| Age group |45 tot 65 year  Population| Age group |65+ year  \
# 530                                    15.0                                   20.0                              0.0
# 1110                                   10.0                                   20.0                              0.0
# 1690                                   15.0                                   15.0                              0.0
# 2316                                   15.0                                   15.0                              0.0
# 2944                                   15.0                                   15.0                              0.0
#
#       Births  Deaths  Total households  Single-person households  Households without children  \
# 530      0.0     0.0               0.0                       5.0                          0.0
# 1110     0.0     0.0              25.0                      30.0                          0.0
# 1690     0.0     0.0              30.0                      30.0                          0.0
# 2316     0.0     0.0              30.0                      30.0                          0.0
# 2944     0.0     0.0              35.0                      35.0                          0.0
#
#       Households with children  Average household size  Care|Young people receiving youth care  \
# 530                        0.0                     1.0                                     0.0
# 1110                       0.0                     1.0                                     0.0
# 1690                       0.0                     1.0                                     0.0
# 2316                       0.0                     1.0                                     0.0
# 2944                       0.0                     1.0                                     0.0
#
#       Healthcare|Wmo clients  ZIPcode  Year  children_0_15  youth_15_25  families_children  elderly_65_plus  \
# 530                     20.0   1105.0  2020            0.0          0.0                0.0              0.0
# 1110                     0.0   1105.0  2021            0.0          0.0                0.0              0.0
# 1690                    10.0   1105.0  2022            0.0          0.0                0.0              0.0
# 2316                    10.0   1105.0  2023            0.0          0.0                0.0              0.0
# 2944                     0.0   1105.0  2024            0.0          0.0                0.0              0.0
#
#       single_households_ind  youth_care_users  wmo_users  youth_care_rate    wmo_rate  children_0_15_growth  \
# 530                     5.0               0.0       20.0              0.0  571.428571                   NaN
# 1110                   30.0               0.0        0.0              0.0    0.000000                   NaN
# 1690                   30.0               0.0       10.0              0.0  333.333333                   NaN
# 2316                   30.0               0.0       10.0              0.0  333.333333                   NaN
# 2944                   35.0               0.0        0.0              0.0    0.000000                   NaN
#
#       youth_15_25_growth  elderly_65_plus_growth  families_children_growth  single_households_ind_growth
# 530                  NaN                     NaN                       NaN                           NaN
# 1110                 NaN                     NaN                       NaN                      5.000000
# 1690                 NaN                     NaN                       NaN                      0.000000
# 2316                 NaN                     NaN                       NaN                      0.000000
# 2944                 NaN                     NaN                       NaN                      0.166667
