# %%
import pandas as pd
import numpy as np
from pathlib import Path
# dates & cleaning
import re
import warnings
warnings.filterwarnings("ignore")
# optional: show full tables in console
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# %%
subsidy_file = "../DATA/amsterdam_subsidies_all_english.xlsx"

# %%
subsidy = pd.read_excel(subsidy_file)

# %%
subsidy.shape
# Out:
# (56484, 14)

# %%
subsidy.head()
# Out:
#    id case_number                  applicant                                        scheme_name  \
# 0   0  2023/05049                   FC Weesp                                Strong Sports Clubs
# 1   1  2023/03251  Foundation Cliffordstudio  Area-based arts and culture activities Distric...
# 2   2  2024/00728         Private individual  Subsidy: sustainable Amsterdam vehicles scrappage
# 3   3  2023/02992         Private individual    Residents' initiatives subsidy scheme Southeast
# 4   4  2024/00245  BIZ-Association Spuibuurt      Business Investment Zone (BIZ) subsidy scheme
#
#                 policy_area        issuing_department                                  project_name periodicity_type  \
# 0                     Sport          Sports and Parks  Versterken van de basis: clubscheidsrechters          One-off
# 1                   Culture             District West                            West Best Talkshow          One-off
# 2  Space and sustainability  Space and Sustainability                           Scrappage bestelbus          One-off
# 3                    Social        District Southeast    Subsidy application Burendag Gooioord 2023          One-off
# 4                   Economy          Economic Affairs    Application BIZ Subsidy 2024 BIZ Spuibuurt          One-off
#
#    amount_requested  amount_granted grant_decision_publication_date  amount_finalized finalization_publication_date  \
# 0            5000.0          3825.0                      2024-03-05            3825.0                           NaT
# 1           20000.0         20000.0                      2023-12-14           20000.0                           NaT
# 2            1500.0          1500.0                      2024-03-26            1500.0                           NaT
# 3            1620.0          1620.0                      2023-09-12            1620.0                           NaT
# 4           74816.0         74236.5                      2024-02-23           74236.5                    2025-12-11
#
#    subsidy_year
# 0        2024.0
# 1        2024.0
# 2        2024.0
# 3        2023.0
# 4        2024.0

# %%
subsidy["policy_area"].unique()
# Out:
# <ArrowStringArray>
# [                        'Sport',                       'Culture',      'Space and sustainability',
#                         'Social',                       'Economy',                     'Education',
#              'Social foundation', 'Urban development and housing',                          'Work',
#                         'Income',             'Internal Services',        'Governance and support',
#                      'Diversity',      'Traffic and public space',    'Services and information\n',
#                          'Youth',                          'Care',                    'Operations',
#                  'Participation',                       'General',                     'Monuments',
#          'Public order & safety']
# Length: 22, dtype: str

# %%
subsidy= subsidy[subsidy["policy_area"].isin(["Care","Education"])]

# %%
subsidy.shape
# Out:
# (4858, 14)

# %%
subsidy.head()
# Out:
#              id case_number                                          applicant  \
# 8   42949676431  2017/01865  "Samen tussen Amstel en IJ" Foundation voor Op...
# 19  34359740813  2021/05033  "Samen tussen Amstel en IJ" Foundation voor Op...
# 23  34359740518  2021/04632  "Samen tussen Amstel en IJ" Foundation voor Op...
# 35  25769805487  2021/04941  "Samen tussen Amstel en IJ" Foundation voor Op...
# 65  42949677602  2023/02558  "Samen tussen Amstel en IJ" Foundation voor Op...
#
#                                           scheme_name policy_area         issuing_department  \
# 8            Onderwijsvoorzieningen primair Education   Education  Education, Youth and Care
# 19  Budget item subsidy and one-off initiatives OJ...   Education  Education, Youth and Care
# 23  Budget item subsidy and one-off initiatives OJ...   Education  Education, Youth and Care
# 35                               VLOA, vz. Piekaanpak   Education  Education, Youth and Care
# 65                         Amsterdamse Familie School   Education  Education, Youth and Care
#
#                                        project_name periodicity_type  amount_requested  amount_granted  \
# 8                    11e groep nieuwkomersonderwijs          One-off           40000.0         23000.0
# 19             Amsterdam Toelage voor het jaar 2021          One-off          533821.0        533821.0
# 23  Amsterdam Toelage voor het schooljaar 2021-2022         Periodic          533821.0             NaN
# 35                        Amsterdamse Familieschool          One-off               NaN             NaN
# 65                        Amsterdamse Familieschool          One-off         2160000.0       1080000.0
#
#    grant_decision_publication_date  amount_finalized finalization_publication_date  subsidy_year
# 8                              NaT           23000.0                           NaT        2017.0
# 19                             NaT          533821.0                    2023-02-03        2021.0
# 23                             NaT               NaN                           NaT        2021.0
# 35                             NaT               NaN                           NaT        2021.0
# 65                      2023-12-14               NaN                           NaT        2023.0

# %%
subsidy["amount"] = subsidy["amount_finalized"]
subsidy["amount"] = subsidy["amount"].fillna(subsidy["amount_granted"])
subsidy["amount"] = subsidy["amount"].fillna(subsidy["amount_requested"])

# %%
subsidy = subsidy[["subsidy_year", "policy_area", "amount"]]

# %%
subsidy.head()
# Out:
#     subsidy_year policy_area     amount
# 8         2017.0   Education    23000.0
# 19        2021.0   Education   533821.0
# 23        2021.0   Education   533821.0
# 35        2021.0   Education        NaN
# 65        2023.0   Education  1080000.0

# %%
subsidy["subsidy_year"] = pd.to_numeric(subsidy["subsidy_year"], errors="coerce")

# %%
subsidy = subsidy.dropna(subset=["subsidy_year"])

# %%
subsidy["subsidy_year"] = subsidy["subsidy_year"].astype(int)

# %%
subsidy_ts = subsidy.groupby(
    ["subsidy_year", "policy_area"]
)["amount"].sum().reset_index()

# %%
subsidy_ts = subsidy_ts.pivot(
    index="subsidy_year",
    columns="policy_area",
    values="amount"
).reset_index()

# %%
subsidy_ts = subsidy_ts.sort_values("subsidy_year")

# %%
subsidy_ts["education_yoy"] = subsidy_ts["Education"].pct_change()
subsidy_ts["care_yoy"] = subsidy_ts["Care"].pct_change()

# %%
subsidy_ts["t"] = range(len(subsidy_ts))

# %%
subsidy_ts["edu_lag1"] = subsidy_ts["Education"].shift(1)
subsidy_ts["edu_lag2"] = subsidy_ts["Education"].shift(2)

subsidy_ts["care_lag1"] = subsidy_ts["Care"].shift(1)
subsidy_ts["care_lag2"] = subsidy_ts["Care"].shift(2)

# %%
subsidy_ts["edu_roll3"] = subsidy_ts["Education"].rolling(3).mean()
subsidy_ts["care_roll3"] = subsidy_ts["Care"].rolling(3).mean()

# %%
subsidy_ts.shape
# Out:
# (12, 12)

# %%
subsidy_ts.to_csv("../data_clean/subsidies.csv", index=False)
